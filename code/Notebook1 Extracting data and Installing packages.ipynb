# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# a nice way of filtering out deprecated warnings
import warnings
warnings.filterwarnings("ignore")


#importing visualisation tools 
import folium

# %%
trainDf = pd.read_csv("/Users/carlensikora/Documents/UNI /Year_3/Sem 2/Applied Data Science/mast30034_2021_s2_project_1-CpntSCurvy/raw_data/NYC_Transit_Subway_Entrance_And_Exit_Data.csv")
print(trainDf)


COORDS = ['Station Latitude', 'Station Longitude']

print('Description!!')
print(trainDf[COORDS].describe())

xRange = [trainDf['Station Longitude'].min(), trainDf['Station Longitude'].max()]
yRange = [trainDf['Station Latitude'].min(), trainDf['Station Latitude'].max()]

xRange, yRange
# Out:
#      Division               Line        Station Name  Station Latitude  \
# 0         BMT           4 Avenue             25th St         40.660397
# 1         BMT           4 Avenue             25th St         40.660397
# 2         BMT           4 Avenue             36th St         40.655144
# 3         BMT           4 Avenue             36th St         40.655144
# 4         BMT           4 Avenue             36th St         40.655144
# ...       ...                ...                 ...               ...
# 1863      IRT  White Plains Road          Simpson St         40.824073
# 1864      IRT  White Plains Road          Simpson St         40.824073
# 1865      IRT  White Plains Road  Wakefield-241st St         40.903125
# 1866      IRT  White Plains Road  Wakefield-241st St         40.903125
# 1867      IRT  White Plains Road  Wakefield-241st St         40.903125
#
#       Station Longitude Route1 Route2 Route3 Route4 Route5  ...    ADA  \
# ...

# %%
#initialise a map
#m = folium.Map(tiles="Stamen Terrain", zoom_start=10)

# save map
#m.save('/Users/carlensikora/Documents/UNI /Year_3/Sem 2/Applied Data Science/mast30034_2021_s2_project_1-CpntSCurvy/plots/map.html')

# show map
#note map is not zoomed in at all.
#m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
mcoords = trainDf[COORDS].describe().loc[["50%"]].values[0]

#plot a map showing all subway stations around NYC

nyc_m = folium.Map(location=mcoords, tiles="Stamen Terrain", zoom_start=10)

nyc_m.save('/Users/carlensikora/Documents/UNI /Year_3/Sem 2/Applied Data Science/mast30034_2021_s2_project_1-CpntSCurvy/plots/folium_nyc.html')

trainDf[['Station Latitude','Station Longitude']]

for index, row in trainDf.iterrows():
    #print(row['c1'], row['c2'])
    folium.Circle(location = [row['Station Latitude'], row['Station Longitude']], radius = 250, fill=True).add_to(nyc_m)

#40.660397         -73.998091

nyc_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#The below is experimentation

# %%
def latitude_to_mercator(coords):
    """
    Function which converts an array of latitude coordinates 
    into its mercator coordinate representation
    """
    k = 6378137
    converted = list()
    for lat in coords:
        converted.append(np.log(np.tan((90 + lat) * np.pi/360.0)) * k)
    return converted

def longitude_to_mercator(coords):
    """
    Function which converts an array of longitude coordinates 
    into its mercator coordinate representation
    """
    k = 6378137
    converted = list()
    for lon in coords:
        converted.append(lon * (k * np.pi/180.0))
    return converted

# %%
print(trainDf[['Station Latitude','Station Longitude']])

trainDf[['StationX','StationY']]
# Out:
#       Station Latitude  Station Longitude
# 0            40.660397         -73.998091
# 1            40.660397         -73.998091
# 2            40.655144         -74.003549
# 3            40.655144         -74.003549
# 4            40.655144         -74.003549
# ...                ...                ...
# 1863         40.824073         -73.893064
# 1864         40.824073         -73.893064
# 1865         40.903125         -73.850620
# 1866         40.903125         -73.850620
# 1867         40.903125         -73.850620
#
# [1868 rows x 2 columns]
#           StationX      StationY
# 0     4.526295e+06 -1.251477e+07
# 1     4.526295e+06 -1.251477e+07
# 2     4.525710e+06 -1.251698e+07
# 3     4.525710e+06 -1.251698e+07
# 4     4.525710e+06 -1.251698e+07
# ...            ...           ...
# 1863  4.544515e+06 -1.247250e+07
# 1864  4.544515e+06 -1.247250e+07
# 1865  4.553315e+06 -1.245549e+07
# 1866  4.553315e+06 -1.245549e+07
# 1867  4.553315e+06 -1.245549e+07
#
# ...

# %%
#inserting circles where all train stations are
from bokeh.plotting import figure, show
from bokeh.tile_providers import get_provider, Vendors

# to display bokeh plots inside jupyter, we need to use output_notebook
from bokeh.io import reset_output, output_notebook

reset_output()
output_notebook()


TILE = get_provider("STAMEN_TERRAIN_RETINA")

#!!!!
dropoff = figure(x_range=longitude_to_mercator(xRange), y_range=latitude_to_mercator(yRange),
       x_axis_type="mercator", y_axis_type="mercator")

dropoff.add_tile(TILE)

dropoff.title.text = "Train Stations in NYC"

#['Station Latitude', 'Station Longitude']

# convert to mercer
trainDf['StationX'] = trainDf['Station Latitude'].apply(lambda x: longitude_to_mercator([x])[0])
trainDf['StationY'] = trainDf['Station Longitude'].apply(lambda x: latitude_to_mercator([x])[0])

# plot circles (source = data source)
dropoff.circle(x='StationX', y='StationY', 
         size=5, color="pink", fill_color="red", fill_alpha=0.5, 
         source= trainDf[['StationX','StationY']])


show(dropoff)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1786">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f3af9b86-1e8d-48f1-9d9f-56fce606e6d2" data-root-id="1788"></div>
# None
